# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/processed_stars/kitchen/train")
df
# Out:
#      periodically:2 handwash_and:1 if:2 sharpeners.as:1 overpriced:1 whole:1 german_i:1 cost:1 going:1 admit:1 you_uses:1 in_these:1 carpal:1 them_up:1 using:1 throw:1 steel.these_are:1 like_in:1 best_of:1 heavy_that:1 as:2 are_not:1 an:1 periodically_you:1 stage:1 to_handwash:1 these_knives:3 rust:1 cost_of:1 <num>:2 something_heavy:1 effortless:1 secret_to:1 but:1 i_think:1 stainless_steel.these:1 easy:1 use_in:1 conventional_wisdom:1 sharpen:3 oil_cloth:1 sharpen_and:1 are_very:1 knife.i_admit:1 get_ridiculously:1 stage_knife:1 like:1 wisdom_advice:1 knife.i:1 are_overated:1 light:2 machine_but:1 you_throw:1 great:1 knives:7 and_can:1 picking_them:1 get_something:1 syndrome?they:1 that:1 light_oil:1 knife_sharpeners.as:1 if_you:2 for_the:1 bargain:1 their_edge:1 steel_they:1 knife.it's_not:1 knives_do:1 that_promotes:1 with_the:1 of_surgical:1 henckels:1 to_sharpen:1 those_cheap:1 to_caring:1 many:1 up:1 why:1 these_these:1 effortless_if:1 sharp:1 use:1 overated_and:1 they_use:1 t
# ...

# %%
df = df.rename(columns={"periodically:2 handwash_and:1 if:2 sharpeners.as:1 overpriced:1 whole:1 german_i:1 cost:1 going:1 admit:1 you_uses:1 in_these:1 carpal:1 them_up:1 using:1 throw:1 steel.these_are:1 like_in:1 best_of:1 heavy_that:1 as:2 are_not:1 an:1 periodically_you:1 stage:1 to_handwash:1 these_knives:3 rust:1 cost_of:1 <num>:2 something_heavy:1 effortless:1 secret_to:1 but:1 i_think:1 stainless_steel.these:1 easy:1 use_in:1 conventional_wisdom:1 sharpen:3 oil_cloth:1 sharpen_and:1 are_very:1 knife.i_admit:1 get_ridiculously:1 stage_knife:1 like:1 wisdom_advice:1 knife.i:1 are_overated:1 light:2 machine_but:1 you_throw:1 great:1 knives:7 and_can:1 picking_them:1 get_something:1 syndrome?they:1 that:1 light_oil:1 knife_sharpeners.as:1 if_you:2 for_the:1 bargain:1 their_edge:1 steel_they:1 knife.it's_not:1 knives_do:1 that_promotes:1 with_the:1 of_surgical:1 henckels:1 to_sharpen:1 those_cheap:1 to_caring:1 many:1 up:1 why:1 these_these:1 effortless_if:1 sharp:1 use:1 overated_and:1 they_use:1 the_machine:1 promotes:1 cheaper_steel:1 as_long:1 steel:1 oil:1 to:3 always:1 machine:1 home:1 heavy:2 <num>_whole:1 often_why:1 sharpeners.as_long:1 whole_sets:1 your_knives:1 or_made:1 long_nor:1 think_german:1 or_wusthoff:1 hold:1 hold_their:1 the_cost:1 not_heavy:1 wusthoff_knife.i:1 can_you:1 throw_them:1 your_knife:1 tunnel:1 sharpen_your:1 best:1 dishwash_always:1 knives_are:2 are:5 they_are:1 them.the:1 an_all:1 home_chefs:1 overated:1 nor_can:1 you_handwash:1 a_light:1 a_great:1 german_or:1 do_not:1 steel.these:1 heavy_german:1 with:1 long_as:1 handwash:3 often:1 them_in:1 can_get:2 or:2 overpriced_these:1 for:2 those:1 made:1 of:3 they:2 sharp_using:1 picking:1 them:2 are_light:1 what:1 purpose_knife.it's:1 ridiculously:1 in_the:1 the_cheaper:1 and_sharpen:2 these:4 cut_with:1 all_purpose:1 purpose:1 and:4 you:6 cheap_<num>:1 not_hold:1 cheaper:1 knives_often:1 is_effortless:1 what_many:1 of_them.the:1 get_<num>:1 rust_if:1 knife.it's:1 <num>_stage:1 admit_the:1 cloth:1 as_you:1 you_dishwash:1 against:2 all:1 wusthoff:1 against_conventional:1 can:4 dishwash:1 sets_for:1 in_an:1 your:2 get:3 bargain_you:1 knife:2 can_cut:1 i'm:1 handwash_these:1 german_knives:1 one:1 caring_for:1 ridiculously_sharp:1 wisdom:1 you_can:2 handwash_a:1 is:2 chefs_like:1 edge_as:1 in:3 stainless:1 made_of:1 surgical_stainless:1 are_a:1 chefs:1 syndrome?they_are:1 great_bargain:1 edge:1 sharpen_periodically:1 something:1 conventional:1 them.the_secret:1 long:2 but_they:1 is_to:1 german:3 going_against:1 knives_picking:1 cloth_and:1 for_your:1 surgical:1 i:1 carpal_tunnel:1 the_best:1 knives_rust:1 and_overpriced:1 a:2 tunnel_syndrome?they:1 henckels_or:1 secret:1 why_get:1 uses_knives:1 knife_is:1 up_is:1 i'm_going:1 not:3 nor:1 knives_periodically:1 light_knives:1 of_one:1 very:1 one_henckels:1 many_home:1 uses:1 cut:1 easy_to:1 using_those:1 very_easy:1 not_german:1 advice:1 the:4 promotes_carpal:1 against_what:1 do:1 think:1 always_handwash:1 their:1 sets:1 cheap:1 caring:1 #label#:4.0": "Text"})

# %%
df.head(10)
# Out:
#                                                 Text
# 0  it_is:1 good:1 it_were:1 that_it:1 this_is:1 t...
# 1  a_few:1 non-standard_batteries:1 i_like:1 case...
# 2  called:1 very_stale:1 popped_corn:1 worst:1 an...
# 3  filled_order:1 bookplates_easy:1 monet_bookpla...
# 4  amount_of:1 just_a:1 stars:1 copper_salt:1 nic...
# 5  the_blender:1 mentioned:1 it:10 as_mentioned:1...
# 6  one_extra:1 it_is:1 for_one:1 this_is:2 one:2 ...
# 7  great:1 the_place:1 up_the:1 window_fan:1 this...
# 8  stains:1 are_going:1 cover:5 on:1 found:1 both...
# 9  i:3 could_make:1 a_few:1 my_husband:1 us_the:1...

# %%
df2=pd.read_csv("/content/drive/MyDrive/processed_stars/kitchen/test")
df2
# Out:
#      have_limited:2 which:2 available:2 to_use:1 version_this:1 store_which:1 gallon:1 a_lid:2 8-piece:1 pan:1 pieces_since:1 wok-like):1 truly_"missing":1 great_gallon:1 much_more:1 immediately:1 soft-touch:1 was_pleased:1 is_no:1 though_the:1 coated:1 the_slightly:1 as:3 am:1 physical_store:1 that_i:1 requires:1 saucier:5 available_however:1 high:1 and_it:1 was_only:1 <num>_qt:3 skillet_this:1 set_and:1 non-stick_coating:1 <num>:3 of_a:2 with_the:1 cooking_requires:1 stainless-steel_saucier:1 high_temperature:1 use_in:1 wok-like)_even:1 that_amazon:1 rating.this:1 some:1 upon:1 the_absense:1 with_this:1 this_set:2 no_open:1 there_is:1 qt_stock:1 stainless-steel:5 subsequently:1 amazon_had:1 hence_the:1 the_truly:1 great:1 immediately_upon:1 i_was:1 "missing"_pieces:1 the_farberware:1 amazon:1 however_as:1 8-piece_set:1 not_for:1 the_design:1 will_have:1 however_i:1 receipt:1 i_subsequently:1 most:1 the_purchase:1 now_discontinued:1 absense_of:1 difficult_to:1 have_the:1 to_work:1 s
# ...

# %%
df2.rename(columns={'have_limited:2 which:2 available:2 to_use:1 version_this:1 store_which:1 gallon:1 a_lid:2 8-piece:1 pan:1 pieces_since:1 wok-like):1 truly_"missing":1 great_gallon:1 much_more:1 immediately:1 soft-touch:1 was_pleased:1 is_no:1 though_the:1 coated:1 the_slightly:1 as:3 am:1 physical_store:1 that_i:1 requires:1 saucier:5 available_however:1 high:1 and_it:1 was_only:1 <num>_qt:3 skillet_this:1 set_and:1 non-stick_coating:1 <num>:3 of_a:2 with_the:1 cooking_requires:1 stainless-steel_saucier:1 high_temperature:1 use_in:1 wok-like)_even:1 that_amazon:1 rating.this:1 some:1 upon:1 the_absense:1 with_this:1 this_set:2 no_open:1 there_is:1 qt_stock:1 stainless-steel:5 subsequently:1 amazon_had:1 hence_the:1 the_truly:1 great:1 immediately_upon:1 i_was:1 "missing"_pieces:1 the_farberware:1 amazon:1 however_as:1 8-piece_set:1 not_for:1 the_design:1 will_have:1 however_i:1 receipt:1 i_subsequently:1 most:1 the_purchase:1 now_discontinued:1 absense_of:1 difficult_to:1 have_the:1 to_work:1 similar_i:1 on_this:1 for_the:1 put:1 process_hence:1 set:3 pot_which:1 this_is:1 limited_use:1 though:1 millenium_soft-touch:1 item:3 lid_in:1 it_is:2 good_"make-do":1 more:1 stock_pot:1 some_key:1 saucier_is:1 found:1 cooking_(i.e.:1 stainless-steel_"missing":1 use:4 above:1 is_similar:1 as_most:1 however:2 find:1 not:1 requires_the:1 to:4 cooking_with:1 qt_coated:1 use_the:1 stock:3 "missing"_<num>:1 low:1 slightly:1 even_though:1 even:1 a_physical:1 set_now:1 upon_receipt:1 appreciate_the:1 the_millenium:1 physical:1 this:5 for_high:1 item_will:1 receipt_however:1 to_find:1 is_strange:1 plan:1 "make-do"_for:1 a_<num>:1 the_stainless-steel:2 stock_on:2 the_cooking:1 temperature_cooking:2 it_to:1 qt:3 which_was:1 better:1 since_they:1 hence:1 are:1 they_have:1 gallon_saucier:1 pot:1 non-stick:1 cooking:5 use_now:1 and_i:1 set_while:1 a_great:1 the_non-stick:1 work_immediately:1 lid_during:1 one_of:1 now_that:1 i_plan:1 lower_rating.this:1 use_of:1 key_pieces:1 coating:1 for_cooking:1 on:2 for:5 cookware:1 of:3 discontinued_as:1 the_<num>:1 discontinued:1 on_that:1 while_i:1 they:1 lid:3 saucier_with:1 saucier_cooking:1 work:1 no:1 i_am:1 was:2 in_the:1 version:2 item_the:1 soft-touch_stainless-steel:1 pan_for:1 "missing"_some:1 stainless-steel_version:2 had_the:1 skillet:1 a_much:1 absense:1 occasional_use:1 me:1 and:2 lower:1 much:2 similar:1 version_much:1 there:1 sets_are:1 much_better:1 pieces:2 during_the:1 with:3 saucier_(i.e.:1 is_difficult:1 qt_stainless-steel:1 rating.this_saucier:1 purchase_and:1 a_good:1 difficult:1 above_i:1 put_it:1 item_is:1 good:1 had:1 limited_open:1 i_appreciate:1 stainless-steel_cookware:1 of_the:1 find_i:1 a_skillet:1 "missing":3 plan_to:1 that:3 (i.e._low:1 which_is:1 is_a:3 that_item:1 pleased:2 open_stock:2 for_occasional:1 pleased_with:1 with_lid:1 this_item:2 appreciate:1 since:1 design:1 strange_to:1 available_in:1 for_this:1 one:1 i_have:1 in_a:2 as_there:1 it:3 is:8 noted_above:1 truly:1 the_8-piece:1 in:3 most_saucier:1 cookware_sets:1 are_"missing":1 store:1 low_temperature:1 temperature:2 pleased_that:1 is_not:1 while:1 open:2 cooking_process:1 better_pan:1 millenium_stainless-steel:1 subsequently_found:1 occasional:1 i:7 i_put:1 slightly_lower:1 a:8 farberware:1 purchase:1 to_me:1 me_as:1 lid_for:1 noted:1 now:2 (i.e.:2 key:1 farberware_millenium:1 coated_saucier:1 limited:2 strange:1 design_is:1 have:3 very:1 during:1 the_use:1 cooking_it:1 "make-do":1 saucier_available:1 (i.e._wok-like):1 am_very:1 very_pleased:1 coating_for:1 only:1 the:14 will:1 process:1 millenium:2 as_noted:1 found_a:1 sets:1 only_available:1 #label#:4.0': 'Text'}, inplace=True)

# %%
df2.head(10)
# Out:
#                                                 Text
# 0  but_but:1 and:1 immediately:1 sent_to:1 the_qu...
# 1  to_dirt:1 to_try:1 at:1 into_the:1 vacuum...ag...
# 2  i:5 called:1 feeder_with:1 of:2 csr:1 seemed_t...
# 3  like_a:1 nothing_like:1 wire_cutter:1 knife_th...
# 4  a:3 thick_and:1 things_constantly:1 recommend_...
# 5  rubber.i've:1 holds_the:1 delonghi:3 is:1 delo...
# 6  of:1 and:2 i_come:1 in_an:1 awkward_angle:1 wo...
# 7  of:1 they_werem:1 they_are:1 hardware_they:1 c...
# 8  a:1 cut:1 favorite:1 cut_a:1 replacement_was:1...
# 9  hoping:1 manufactured_in:1 are:3 henckels_they...

# %%
import re
def clean_text(text):
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    return text.lower().strip()
df['Text'] = df['Text'].apply(clean_text)
df2['Text'] = df2['Text'].apply(clean_text)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(df['Text'])

# %%
X_train = tokenizer.texts_to_sequences(df['Text'])
X_test = tokenizer.texts_to_sequences(df2['Text'])

# %%
X_train
# Out:
# [[45,
#   37,
#   3342,
#   161,
#   86,
#   13,
#   49,
#   204,
#   484,
#   155,
#   485,
#   7,
#   10,
#   2843,
#   7631,
#   157,
#   175,
#   19,
#   699,
#   1694,
#   3343,
#   581,
#   88,
#   90,
#   2,
#   101,
#   15,
#   8,
#   4162,
#   55,
#   176,
#   1320,
#   34,
#   1064,
#   3344,
#   7632,
#   1532,
#   5,
#   5338,
#   4,
#   1],
#  [252,
#   699,
#   5339,
#   223,
#   311,
#   7633,
#   29,
#   26,
#   3345,
#   76,
#   700,
#   2146,
#   7634,
#   7635,
#   424,
#   3346,
#   344,
#   14,
#   34,
#   73,
#   7636,
#   795,
#   1065,
#   4163,
#   1533,
#   366,
#   49,
#   7637,
#   2443,
#   321,
#   1321,
#   92,
#   1534,
#   5340,
#   734,
#   4164,
#   2844,
#   878,
#   5341,
#   74,
#   86,
#   193,
#   796,
#   3347,
#   95,
#   523,
#   7638,
#   7639,
#   7640,
#   582,
#   7641,
#   3348,
#   38,
#   7642,
#   2845,
#   1066,
#   229,
#   6,
#   662,
#   1322,
#   1224,
#   879,
#   2846,
#   1067,
#   1417,
#   1695,
#   5342,
#   3349,
# ...

# %%
X_test
# Out:
# [[3,
#   1103,
#   682,
#   335,
#   6,
#   555,
#   61,
#   67,
#   2,
#   101,
#   87,
#   22,
#   162,
#   7003,
#   6902,
#   1404,
#   98,
#   17,
#   2587,
#   93,
#   5,
#   4,
#   660,
#   37,
#   175,
#   122,
#   822,
#   336,
#   5166,
#   20,
#   6642,
#   7074,
#   90,
#   3054,
#   1192,
#   14,
#   853,
#   3260,
#   271,
#   16,
#   150,
#   593,
#   108,
#   1],
#  [676,
#   29,
#   331,
#   566,
#   234,
#   4462,
#   1795,
#   6781,
#   319,
#   8004,
#   6283,
#   28,
#   1808,
#   67,
#   1185,
#   224,
#   3894,
#   5579,
#   1311,
#   7522,
#   83,
#   149,
#   14,
#   2744,
#   571,
#   795,
#   1053,
#   5871,
#   7524,
#   69,
#   718,
#   299,
#   49,
#   237,
#   802,
#   1016,
#   734,
#   5487,
#   355,
#   5401,
#   427,
#   2084,
#   141,
#   6765,
#   9325,
#   4437,
#   153,
#   559,
#   2506,
#   1039,
#   771,
#   213,
#   5740,
#   523,
#   62,
#   1666,
#   43,
#   3591,
#   255,
#   11,
#   374,
#   5811,
#   508,
#   25,
#   6,
#   4890,
# ...

# %%
from tensorflow.keras.datasets import imdb
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=88586)

# %%
x_train
# Out:
# array([list([1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]),
# ...

# %%
from tensorflow.keras.preprocessing import sequence

# %%
x_train=sequence.pad_sequences(x_train, maxlen=100)
x_test=sequence.pad_sequences(x_test, maxlen=100)

# %%
x_train.shape,x_test.shape
# Out:
# ((25000, 100), (25000, 100))

# %%
import numpy as np

# %%
print(np.max(x_train))
print(np.max(x_test))
# Out:
# 88585
# 88582

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, Dropout, LSTM, Bidirectional,BatchNormalization

from keras.regularizers import l2

# %%
vocab_size = 88586
maxlen = 100

# %%
model=Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=maxlen))
model.add(SimpleRNN(128, return_sequences=False, activation='tanh', kernel_regularizer=l2(0.01)))
model.add(Dense(1,activation='sigmoid'))
model.summary()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_data=(x_test, y_test))
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ simple_rnn_1 (SimpleRNN)             │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# ...

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=128, input_length=maxlen))
model.add(LSTM(128, return_sequences=False, activation='tanh', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3))  # Reduced to avoid excessive dropout
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.4))
model.add(Dense(32, activation='relu', kernel_regularizer=l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
model.add(Dense(16, activation='relu', kernel_regularizer=l2(0.01)))
model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ ?                           │     0 (unbuilt) │
# ...

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(
    x_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=64,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 139s 426ms/step - accuracy: 0.5980 - loss: 2.6898 - val_accuracy: 0.7632 - val_loss: 1.1889 - learning_rate: 0.0010
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 136s 436ms/step - accuracy: 0.8928 - loss: 0.6929 - val_accuracy: 0.8326 - val_loss: 0.5150 - learning_rate: 0.0010
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 139s 427ms/step - accuracy: 0.9526 - loss: 0.2369 - val_accuracy: 0.7258 - val_loss: 0.7638 - learning_rate: 0.0010
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 142s 425ms/step - accuracy: 0.9701 - loss: 0.1332 - val_accuracy: 0.8182 - val_loss: 0.5279 - learning_rate: 0.0010
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 141s 421ms/step - accuracy: 0.9750 - loss: 0.0999 - val_accuracy: 0.7998 - val_loss: 0.6708 - learning_rate: 0.0010
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 143s 426ms/step - accuracy: 0.9884 - loss: 0.0628 - val_accuracy: 0.8128 - val_loss: 0.5833 - learning_rate: 5.0000e-04
# Epoch 7/50
# ...

# %%
## Evaluate on the training set
train_loss, train_accuracy = model.evaluate(x_train[:int(len(x_train)*0.8)],
                                            y_train[:int(len(y_train)*0.8)],
                                            verbose=0)

# Evaluate on the validation (testing) set
val_loss, val_accuracy = model.evaluate(x_train[int(len(x_train)*0.8):],
                                        y_train[int(len(y_train)*0.8):],
                                        verbose=0)

# Print the results
print(f"Early Stopping Training Loss: {train_loss:.4f}")
print(f"Early Stopping Training Accuracy: {train_accuracy:.4f}")
print(f"Early Stopping Validation Loss: {val_loss:.4f}")
print(f"Early Stopping Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Early Stopping Training Loss: 0.3197
# Early Stopping Training Accuracy: 0.9644
# Early Stopping Validation Loss: 0.5150
# Early Stopping Validation Accuracy: 0.8326

# %%
import matplotlib.pyplot as plt

# %%
# Extract values from history
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Plotting Loss
plt.figure(figsize=(12, 5))

# %%
plt.plot(train_loss, label='Training Loss', marker='o')
plt.plot(val_loss, label='Validation Loss', marker='o')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid()
plt.show()

# %%
# Plotting Accuracy
plt.plot(train_accuracy, label='Training Accuracy', marker='o')
plt.plot(val_accuracy, label='Validation Accuracy', marker='o')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()
